# %%
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field

input_file = "prepare_data/{dataset}_input.csv"
table_list_wo_des_file = "prepare_data/{dataset}_table_list_wo_des.txt"
common_prompt = ChatPromptTemplate(
    [
        (
            "human",
            """This is the database and table list

{table_list_text}

Based on the database and table list, please select the tables that are most related to the user question.
Only select the tables that are listed in the database and table list.

{user_question}
""",
        )
    ]
)


class SelectedTable(BaseModel):
    table_name: str = Field(description="The name of the table")
    db_name: str = Field(description="The name of the database")


class SelectedTableList(BaseModel):
    selected_table_list: list[SelectedTable] = Field(
        description="The list of selected tables"
    )


configs = [
    {
        "dataset": "dev",
        "method": "llm",
        "model": "llama3.2:3b",
        "model_config": {
            "temperature": 0.0,
        },
        "input_file": input_file,
        "table_list_file": table_list_wo_des_file,
        "output_file": "inference_data/llama32_3b_retrieval_wo_des_{dataset}.csv",
        "prompt": common_prompt,
    }
]

# %%
import pandas as pd
from langchain_core.language_models.chat_models import BaseChatModel
from langchain_ollama import ChatOllama


def retrieve(config: dict):
    if config["method"] == "llm":
        return retrieve_llm(config)
    else:
        raise ValueError(f"Invalid method: {config['method']}")


def gen_selected_table_list(
    llm: BaseChatModel,
    prompt: ChatPromptTemplate,
    table_list_text: str,
    user_question: str,
):
    llm_with_structure = llm.with_structured_output(SelectedTableList)
    msg = prompt.invoke(
        {"table_list_text": table_list_text, "user_question": user_question}
    )
    # print(msg.to_messages()[0].content)
    res: SelectedTableList = llm_with_structure.invoke(msg)
    return res.selected_table_list


def retrieve_llm(config: dict):
    table_list_file = config["table_list_file"].format(dataset=config["dataset"])
    table_list_text = open(table_list_file, "r").read()
    input_file = config["input_file"].format(dataset=config["dataset"])
    df = pd.read_csv(input_file)

    llm = ChatOllama(model=config["model"], **config["model_config"])
    return gen_selected_table_list(
        llm, config["prompt"], table_list_text, df["question"].iloc[0]
    )

# %%
retrieve_llm(configs[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 retrieve_llm(configs[0])
#
# Cell In[18], line 35, in retrieve_llm(config)
#      32 df = pd.read_csv(input_file)
#      34 llm = ChatOllama(model=config["model"], **config["model_config"])
# ---> 35 return gen_selected_table_list(
#      36     llm, config["prompt"], table_list_text, df["question"].iloc[0]
#      37 )
#
# Cell In[18], line 24, in gen_selected_table_list(llm, prompt, table_list_text, user_question)
#      20 msg = prompt.invoke(
#      21     {"table_list_text": table_list_text, "user_question": user_question}
#      22 )
#      23 # print(msg.to_messages()[0].content)
# ---> 24 res: SelectedTableList = llm_with_structure.invoke(msg)
#      25 return res.selected_table_list
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/langchain_core/runnables/base.py:3045, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3043 with set_config_context(config) as context:
#    3044     if i == 0:
# -> 3045         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046     else:
#    3047         input_ = context.run(step.invoke, input_, config)
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/langchain_core/runnables/base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)   5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)    367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)    954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/langchain_ollama/chat_models.py:741, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     734 def _generate(
#     735     self,
#     736     messages: list[BaseMessage],
#    (...)    739     **kwargs: Any,
#     740 ) -> ChatResult:
# --> 741     final_chunk = self._chat_stream_with_aggregation(
#     742         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     743     )
#     744     generation_info = final_chunk.generation_info
#     745     chat_generation = ChatGeneration(
#     746         message=AIMessage(
#     747             content=final_chunk.text,
#    (...)    752         generation_info=generation_info,
#     753     )
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/langchain_ollama/chat_models.py:678, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     669 def _chat_stream_with_aggregation(
#     670     self,
#     671     messages: list[BaseMessage],
#    (...)    675     **kwargs: Any,
#     676 ) -> ChatGenerationChunk:
#     677     final_chunk = None
# --> 678     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     679         if final_chunk is None:
#     680             final_chunk = chunk
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/langchain_ollama/chat_models.py:763, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     756 def _iterate_over_stream(
#     757     self,
#     758     messages: list[BaseMessage],
#     759     stop: Optional[list[str]] = None,
#     760     **kwargs: Any,
#     761 ) -> Iterator[ChatGenerationChunk]:
#     762     is_thinking = False
# --> 763     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     764         if not isinstance(stream_resp, str):
#     765             if stream_resp.get("done") is True:
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/langchain_ollama/chat_models.py:665, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     662 chat_params = self._chat_params(messages, stop, **kwargs)
#     664 if chat_params["stream"]:
# --> 665     yield from self._client.chat(**chat_params)
#     666 else:
#     667     yield self._client.chat(**chat_params)
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/ollama/_client.py:165, in Client._request.<locals>.inner()
#     164 def inner():
# --> 165   with self._client.stream(*args, **kwargs) as r:
#     166     try:
#     167       r.raise_for_status()
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpx/_client.py:868, in Client.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     845 """
#     846 Alternative to `httpx.request()` that streams the response body
#     847 instead of loading it into memory at once.
#    (...)    853 [0]: /quickstart#streaming-responses
#     854 """
#     855 request = self.build_request(
#     856     method=method,
#     857     url=url,
#    (...)    866     extensions=extensions,
#     867 )
# --> 868 response = self.send(
#     869     request=request,
#     870     auth=auth,
#     871     follow_redirects=follow_redirects,
#     872     stream=True,
#     873 )
#     874 try:
#     875     yield response
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/envs/handsonllm/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
